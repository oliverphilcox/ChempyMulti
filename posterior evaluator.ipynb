# %%
from Chempy.wrapper import single_star_optimization
single_star_optimization()
# Out:
# ['Proto-sun_all']
# first minimization for each star separately took:  0 seconds
# step  1 of  1000
# -7.01605884444 -7.01545017054
# calculation so far took 1.5178120136260986  seconds
# step  2 of  1000
# -7.01605884444 -7.01720052155
# calculation so far took 1.84525728225708  seconds
# step  3 of  1000
# -7.01605884444 -7.01858233903
# calculation so far took 2.1737492084503174  seconds
# step  4 of  1000
# -7.01605884444 -7.02375883522
# calculation so far took 2.484922409057617  seconds
# step  5 of  1000
# -7.01605884444 -7.03220112383
# calculation so far took 2.8986623287200928  seconds
# step  6 of  1000
# -7.01605884444 -7.04895867007
# calculation so far took 3.204251766204834  seconds
# step  7 of  1000
# -7.01605884444 -7.13052589297
# calculation so far took 3.5062105655670166  seconds
# step  8 of  1000
# -7.01605884444 -7.27446465495
# calculation so far took 3.8703956604003906  seconds
# step  9 of  1000
# -7.01605884444 -7.33515408182
# ...

# %%
from Chempy.plot_mcmc import restructure_chain
restructure_chain('mcmc/')
# Out:
# blob shape =  (64, 303, 28, 1) probably some runs did not return results and were stored anyway.
# The chain has a length of 303 iterations, each iteration having 64 evaluations/walkers
# Mean posteriors at the beginning and the end of the chain:
# -9.59128555564 -7.01605884444
# Mean posteriors after the burn-in tail is cut out:
# -9.59128555564 -9.66290329722
# We are left with a sample of 4992 posterior evaluations from the converged MCMC chain
# We have 4992 iterations good enough posterior, their posteriors range from
# -6.97530770952 -18.7222973478
# Highest posterior was obtained at parameters:  [[-2.34065158 -2.94133917 -0.33217251  0.5605651   0.52258342]]
# Number of unique posterior values:  2840
# Inferred marginalized parameter distributions are:
# 0 -2.31121414456 +- 0.135741239172
# 1 -2.8860244149 +- 0.187826755028
# 2 -0.278379269419 +- 0.271667412482
# 3 0.563014048494 +- 0.100247017232
# 4 0.511897630511 +- 0.101943339887

# %%
# %pylab inline
positions = np.load('mcmc/posteriorPDF.npy')
med = np.median(positions,axis=0)
low = np.percentile(positions,15.865,axis=0)
up = np.percentile(positions,100-15.865,axis=0)
for i in range(5):
    print("%.2f + %.2f - %.2f" %(med[i],up[i]-med[i],med[i]-low[i]))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# -2.32 + 0.14 - 0.12
# -2.87 + 0.17 - 0.20
# -0.29 + 0.29 - 0.25
# 0.56 + 0.09 - 0.10
# 0.51 + 0.11 - 0.10

# %%
# %load init.ipy
# %pylab inline
from Chempy.parameter import ModelParameters
a = ModelParameters()
from Chempy.score_function import preload_params_mcmc
preload = preload_params_mcmc()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from Chempy.cem_function import posterior_function_mcmc_quick

p,_ = posterior_function_mcmc_quick(med,preload.elements,preload)
print('%.2f' %(p))
# Out:
# -6.93

# %%
-2.32 + 0.14 - 0.12
-2.87 + 0.17 - 0.20
-0.29 + 0.29 - 0.25
0.56 + 0.09 - 0.10
0.51 + 0.11 - 0.10
# Out:
# 0.43000000000000005
