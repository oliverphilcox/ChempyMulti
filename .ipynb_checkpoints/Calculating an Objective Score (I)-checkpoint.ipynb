# %% [markdown]
# ## Create Monte Carlo method to integrate posterior

# %%
# %pylab inline
import mcint
import numpy.random
from Chempy.parameter import ModelParameters
from Chempy.cem_function import posterior_function_for_integration,posterior_function_many_stars
a = ModelParameters()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### TEST with different random generators e.g. gaussian
#
# ### Can we speed up posterior_function_for_integration?
# Limiting factor is the 51 iterations of likelihood function... (takes ~3ms each)

# %%
# Define function to return posterior predictions (must be exponentiated)
def posterior(theta):
    a = ModelParameters()
    post = posterior_function_for_integration(theta)
    posterior = np.exp(post)
    return posterior

sigma = [] # Read prior sigma from parameter file
for i,param_name in enumerate(a.to_optimize):
    sigma.append(a.priors.get(param_name)[1])
    
def sampler(i):
    while True:
        yield random.uniform(np.array(a.p0)-Nsigma[i]*np.array(sigma),np.array(a.p0)+Nsigma[i]*np.array(sigma),size=6)

# %%
Nsamples = [10000,10000,100000] # No MC samples
Nsigma = [1,2,3,3.5] # Width in parameter space
j = 0
integral = []
integral_err = []
for i in range(len(Nsigma)):
    print('Calculating integral %d of %d' %(i,len(Nsigma)))
    domain_size = np.prod(sigma)*(2*Nsigma[i])**len(sigma) # Total domain size
    result,error = mcint.integrate(posterior,sampler(i),n=Nsamples[j],measure=domain_size)
    integral.append(result)
    integral_err.append(error)
# Out:
# Calculating integral 0 of 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6d8e8986be01> in <module>()
#       7     print('Calculating integral %d of %d' %(i,len(Nsigma)))
#       8     domain_size = np.prod(sigma)*(2*Nsigma[i])**len(sigma) # Total domain size
# ----> 9     result,error = mcint.integrate(posterior,sampler(i),n=Nsamples[j],measure=domain_size)
#      10     integral.append(result)
#      11     integral_err.append(error)
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/mcint.py in integrate(integrand, sampler, measure, n)
#       9     total_sq = 0.0
#      10     for x in itertools.islice(sampler, n):
# ---> 11         f = integrand(x)
#      12         total += f
#      13         total_sq += (f**2)
#
# <ipython-input-2-b3c71c5f34cf> in posterior(theta)
#       2 def posterior(theta):
#       3     a = ModelParameters()
# ----> 4     post = posterior_function_for_integration(theta)
#       5     posterior = np.exp(post)
#       6     return posterior
#
# /home/philcox/Chempy/Chempy/cem_function.py in posterior_function_for_integration(changing_parameter)
#    1027         for i, item in enumerate(model_errors):
#    1028                 error_temp = np.ones(len(elements)) * item
# -> 1029                 likelihood_temp, _, _, _, _, _ = likelihood_function(a.stellar_identifier, abundance_list, elements_to_trace, fixed_model_error = error_temp, elements = elements)
#    1030                 likelihood_list.append(likelihood_temp)
#    1031         likelihood = logsumexp(likelihood_list, b = error_weight)
#
# /home/philcox/Chempy/Chempy/data_to_test.py in likelihood_function(stellar_identifier, list_of_abundances, elements_to_trace, **keyword_parameters)
#    1371                 for i,item in enumerate(elements):
#    1372                         el_list.append(item)#.decode('utf-8'))
# -> 1373                 elements = np.hstack(el_list)
#    1374                 model_error = []
#    1375                 for i,item in enumerate(element_list):
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/core/shape_base.py in hstack(tup)
#     281
#     282     """
# --> 283     arrs = [atleast_1d(_m) for _m in tup]
#     284     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     285     if arrs[0].ndim == 1:
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/core/shape_base.py in <listcomp>(.0)
#     281
#     282     """
# --> 283     arrs = [atleast_1d(_m) for _m in tup]
#     284     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     285     if arrs[0].ndim == 1:
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/core/shape_base.py in atleast_1d(*arys)
#      48     res = []
#      49     for ary in arys:
# ---> 50         ary = asanyarray(ary)
#      51         if len(ary.shape) == 0:
#      52             result = ary.reshape(1)
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# KeyboardInterrupt:

# %%
plt.errorbar(Nsigma,integral,yerr=integral_err)
plt.xlabel('Nsigma')
plt.ylabel('Integral value')

# %%
# %timeit -r 1 -n 1 result, error = mcint.integrate(posterior, sampler(),n=Nsamples,measure=domain_size)

# %%
print(result,error)

# %%
d1 = []
d2 = []
d3 = []
Nsigma = 3
for i in range(1000):
    param = random.uniform(np.array(a.p0)-Nsigma*np.array(sigma),np.array(a.p0)+Nsigma*np.array(sigma),size=6)
    param[2] = a.p0[2]
    param[3] = a.p0[3]
    param[4] = a.p0[4]
    param[5] = a.p0[5]
    post = posterior_function_for_integration(param)
    posterior = np.exp(post)
    d1.append(param[0])
    d2.append(param[1])
    d3.append(posterior)
# Out:
# /home/philcox/Chempy/Chempy/data_to_test.py:44: RuntimeWarning: divide by zero encountered in log
#   log_likelihood_list = np.log(list_of_likelihoods)

# %%
plt.scatter(d1,d2,c=(d3))
plt.colorbar()

# %%
# %timeit _ = posterior_function_for_integration([-3.,-3.,-0.8,-0.5,0.6,0.5])
# Out:
# 10 loops, best of 3: 26.4 ms per loop

# %%
plt.scatter(d1,d3)

# %%
# %timeit posterior([-3.,-3.,-0.8,-0.5,0.6,0.5])
# Out:
# 10 loops, best of 3: 26.3 ms per loop

# %% [markdown]
# ## New posterior function with error marginalization

# %%
from Chempy.cem_function import posterior_function_many_stars

def posterior(theta):
    a = ModelParameters()
     post,_ = posterior_function_many_stars(np.array(param),np.inf,a.elements_to_trace)
    posterior = np.exp(post)
    return posterior

# %%
a = ModelParameters()
param = [-3,-3,-0.8,-0.3,0.5,0.6]
pos,abun = posterior_function_many_stars(np.array(param),np.inf,a.elements_to_trace)

# %%
pos,abun = posterior_function_many_stars(np.array(param),np.inf,a.elements_to_trace)

# %%
sol_dat = np.load('Chempy/input/stars/Proto-sun.npy')
sol_dat[1]

# %%
b

# %%
proto_sun = np.load('Chempy/input/stars/Proto-sun.npy')
element_list = np.unique(proto_sun.dtype.names,a.elements_to_trace)[0][:-1]
print(element_list)

# %% [markdown]
# **Spare code**

# %% [markdown]
# def posterior_function_for_integration(changing_parameter,a):
# 	'''
# 	This is the posterior function for a single star with beta-error model.
#
# 	Beta error marginalization MUST be used for this.
#
# 	This is for speeding up Bayes' factor integration
# 	'''
# 	from .data_to_test import likelihood_evaluation
#
# 	# the values in a are updated according to changing_parameters and the prior list is appended
# 	a = extract_parameters_and_priors(changing_parameter, a)
#
# 	# the log prior is calculated
# 	prior = sum(np.log(a.prior))
#
# 	# call Chempy and return the abundances at the end of the simulation = time of star's birth and the corresponding element names as a list
# 	abundance_list,elements_to_trace = cem_real2(a)
#
# 	abundance_list = abundance_list[:-2]
# 	elements_to_trace = elements_to_trace[:-2]
#
# 	proto_sun = np.load('Chempy/input/stars/Proto-sun.npy')
# 	element_list = np.unique(proto_sun.dtype.names,elements_to_trace)[0][:-1] # Remove age
#
# 	## likelihood is calculated (the model error vector is expanded)
# 	from scipy.stats import beta
# 	likelihood_list = []
# 	model_errors = np.linspace(a.flat_model_error_prior[0],a.flat_model_error_prior[1],a.flat_model_error_prior[2])
# 	error_weight = beta.pdf(model_errors, a = a.beta_error_distribution[1], b = a.beta_error_distribution[2])
# 	error_weight/= sum(error_weight)
#
# 	for item in model_errors:
# 		error_temp = np.ones(len(element_list)) * item
# 		likelihood_list.append(likelihood_evaluation(error_temp[:,None], proto_sun[1] , abundance_list, proto_sun[0]))
# 		likelihood = logsumexp(likelihood_list, b = error_weight)
#
# 	likelihood,_,_,_,_ = likelihood_function(a.stellar_identifier, abundance_list, elements_to_trace)
#
# 	return(prior+likelihood)

# %% [markdown]
# ## Try new MC integration package

# %%
from skmonaco import mcquad
result, error = mcquad(lambda xs: np.sqrt(xs[0]**2+xs[1]**2+xs[2]**2),npoints=1e3, xl=[0.,0.,0.], xu=[1.,1.,1.])

# %%
result,error
# Out:
# (0.96113704017884682, 0.0086215293215636413)

# %%
# Define function to return posterior predictions (must be exponentiated)
def posterior(theta):
    a = ModelParameters()
    post = posterior_function_for_integration(theta)
    posterior = np.exp(post)
    return posterior

sigma = [] # Read prior sigma from parameter file
for i,param_name in enumerate(a.to_optimize):
    sigma.append(a.priors.get(param_name)[1])

# %%
Nsamples = [100,10000,100000] # No MC samples
Nsigma = [1,2,3,3.5] # Width in parameter space
j = 0
integral = []
integral_err = []
for i in range(len(Nsigma)):
    print('Calculating integral %d of %d' %(i,len(Nsigma)))
    result,error = mcquad(posterior,npoints=Nsamples[j],xl=a.p0-Nsigma[i]*sigma,xu=a.p0+Nsigma[i]*sigma)
    integral.append(result)
    integral_err.append(error)
# Out:
# Calculating integral 0 of 4
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/philcox/Chempy/Chempy/cem_function.py in shorten_sfr(a)
#      94         try:
# ---> 95                 star = np.load('%s.npy' %(a.stellar_identifier))
#      96         except Exception as ex:
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     369     if isinstance(file, basestring):
# --> 370         fid = open(file, "rb")
#     371         own_fid = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Proto-sun.npy'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5f7201427d51> in <module>()
#       6 for i in range(len(Nsigma)):
#       7     print('Calculating integral %d of %d' %(i,len(Nsigma)))
# ----> 8     result,error = mcquad(posterior,npoints=Nsamples[j],xl=a.p0-Nsigma[i]*sigma,xu=a.p0+Nsigma[i]*sigma)
#       9     integral.append(result)
#      10     integral_err.append(error)
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/skmonaco/uniform.py in mcquad(f, npoints, xl, xu, args, rng, nprocs, seed, batch_size)
#     127     """
#     128     return _MC_Integrator(f,npoints,args=args,
# --> 129             xl=xl,xu=xu,rng=rng,nprocs=nprocs,seed=seed,batch_size=batch_size).run()
#     130
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/skmonaco/mc_base.py in run(self)
#      65     def run(self):
#      66         if self.nprocs == 1:
# ---> 67             return self.run_serial()
#      68         else:
#      69             return self.run_parallel()
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/skmonaco/mc_base.py in run_serial(self)
#      48         f = self.make_integrator()
#      49         for ibatch,batch_size in enumerate(self.batch_sizes):
# ---> 50             batch_sum, batch_sum2 = f(ibatch)
#      51             summ += batch_sum
#      52             sum2 += batch_sum2
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/skmonaco/uniform.py in func(batch_number)
#      39             seed = self.seed_generator.get_seed_for_batch(batch_number)
#      40             return _mc.integrate_uniform(f,batches[batch_number],
# ---> 41                     xl,xu,args=self.args,rng=self.rng,seed=seed)
#      42         return func
#      43
#
# _mc.pyx in skmonaco._mc.integrate_uniform (skmonaco/_mc.c:2677)()
#
# _mc.pyx in skmonaco._mc.run_integral (skmonaco/_mc.c:1546)()
#
# _core.pyx in skmonaco._core.mc_kernel_noargs (skmonaco/_core.c:1757)()
#
# <ipython-input-7-b3c71c5f34cf> in posterior(theta)
#       2 def posterior(theta):
#       3     a = ModelParameters()
# ----> 4     post = posterior_function_for_integration(theta)
#       5     posterior = np.exp(post)
#       6     return posterior
#
# /home/philcox/Chempy/Chempy/cem_function.py in posterior_function_for_integration(changing_parameter)
#    1009         prior = sum(np.log(a.prior))
#    1010
# -> 1011         _,elements = posterior_function_returning_predictions((changing_parameter,a))
#    1012
#    1013         # call Chempy and return the abundances at the end of the simulation = time of star's birth and the corresponding element names as a list
#
# /home/philcox/Chempy/Chempy/cem_function.py in posterior_function_returning_predictions(args)
#     479 	'''
#     480         changing_parameter,a = args
# --> 481         posterior, abundance_list, element_list = posterior_function_predictions(changing_parameter,a)
#     482         return abundance_list,element_list
#     483
#
# /home/philcox/Chempy/Chempy/cem_function.py in posterior_function_predictions(changing_parameter, a)
#     504
#     505         # call Chempy and return the abundances at the end of the simulation = time of star's birth and the corresponding element names as a list
# --> 506         abundance_list,elements_to_trace = cem_real2(a)
#     507
#     508         a.end ,a.time_steps, a.total_mass = backup
#
# /home/philcox/Chempy/Chempy/cem_function.py in cem_real2(a)
#     334 	'''
#     335         ## The time until which Chempy is calculated is cropped to the stellar birth time. Also the SFR should not be below 1/20th of the mean SFR
# --> 336         a = shorten_sfr(a)
#     337         basic_solar = solar_abundances()
#     338         getattr(basic_solar, a.solar_abundance_name)()
#
# /home/philcox/Chempy/Chempy/cem_function.py in shorten_sfr(a)
#      96         except Exception as ex:
#      97                 from . import localpath
# ---> 98                 star = np.load(localpath + 'input/stars/' + a.stellar_identifier + '.npy')
#      99         age_of_star = star['age'][0]
#     100         assert (age_of_star <= 13.0), "Age of the star must be below 13Gyr"
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     417             else:
#     418                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 419                                          pickle_kwargs=pickle_kwargs)
#     420         else:
#     421             # Try a pickle
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     623     version = read_magic(fp)
#     624     _check_version(version)
# --> 625     shape, fortran_order, dtype = _read_array_header(fp, version)
#     626     if len(shape) == 0:
#     627         count = 1
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/lib/format.py in _read_array_header(fp, version)
#     485     #   "fortran_order" : bool
#     486     #   "descr" : dtype.descr
# --> 487     header = _filter_header(header)
#     488     try:
#     489         d = safe_eval(header)
#
# /home/philcox/anaconda3/lib/python3.6/site-packages/numpy/lib/format.py in _filter_header(s)
#     448     tokens = []
#     449     last_token_was_number = False
# --> 450     for token in tokenize.generate_tokens(StringIO(asstr(s)).read):
#     451         token_type = token[0]
#     452         token_string = token[1]
#
# /home/philcox/anaconda3/lib/python3.6/tokenize.py in _tokenize(readline, encoding)
#     626                     yield TokenInfo(COMMENT, token, spos, epos, line)
#     627
# --> 628                 elif token in triple_quoted:
#     629                     endprog = _compile(endpats[token])
#     630                     endmatch = endprog.match(line, pos)
#
# KeyboardInterrupt:
