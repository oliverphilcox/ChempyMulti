# %%
# First load in TNG dataset
import numpy as np
positions=np.load('/data/ohep2/MPIAData/SimData/100MSun/posteriorPDF.npy')

draws=positions[:4,:]

cubes=[]
abuns=[]
for i,params in enumerate(draws):
    if i%10==0:
        print i
    from Chempy.parameter import ModelParameters
    a=ModelParameters()
    from Chempy.cem_function import extract_parameters_and_priors
    from Chempy.wrapper import Chempy
    a2=extract_parameters_and_priors(params,a)
    cube,abun=Chempy(a2)
    #cubes.append(cube.cube)
    abuns.append(abun)
# Out:
# 0

# %%
cube.cube['sfr']
# Out:
# array([ 0.00010621,  0.01062076,  0.01939229,  0.02655608,  0.03232558,
#         0.03688926,  0.04041334,  0.04304425,  0.0449108 ,  0.04612612,
#         0.04678946,  0.04698771,  0.04679683,  0.04628307,  0.0455041 ,
#         0.04450997,  0.04334407,  0.04204382,  0.04064147,  0.03916464,
#         0.03763692,  0.03607838,  0.03450595,  0.03293387,  0.03137399,
#         0.02983611,  0.02832821,  0.02685673])

# %%
meds=np.median(positions,axis=0)
from Chempy.parameter import ModelParameters
a=ModelParameters()
from Chempy.cem_function import extract_parameters_and_priors
from Chempy.wrapper import Chempy
a2=extract_parameters_and_priors(meds,a)
cubeM,abunM=Chempy(a2)

np.savez('TNG100FreeFreeData.npz',median=abunM,abundances=abuns)

# %%
def wt_av(abun):
    return (16.*abun['O']+24.*abun['Mg']+28.*abun['Si'])/(16.+24.+28.)

plt.plot(abunM['Fe'],wt_av(abunM),lw=3,c='k')
for i in range(len(abuns)):
    ab=abuns[i]
    plt.plot(ab['Fe'],wt_av(ab),alpha=0.2,ls='-')
plt.show()

# %%
# load in data
dat=np.load('TNG40FreeFreePredictions.npz')

def wt_av(i):
    return (16.*dat['O'][i]+24.*dat['Mg'][i]+28.*dat['Si'][i])/(16.+24.+28.)

# %%
plt.plot(dat['medFe'],dat['medMg'],c='k',alpha=1)
FS=14
for i in range(100):
    plt.plot(dat['Fe'][i],wt_av(i),alpha=0.2)
plt.xlabel(r'[Fe/H]',fontsize=FS)
plt.ylabel(r'[$\alpha$/Fe]',fontsize=FS)
plt.show()

# %%
allFe=dat['Fe'].ravel()
filt=np.where(allFe>-2.)
allFe=allFe[filt]
allalpha=(16.*dat['O'].ravel()+28.*dat['Si'].ravel()+24.*dat['Mg'].ravel())/(16.+24.+28.)
allalpha=allalpha[filt]
import cmocean
plt.hist2d(allFe,allalpha,bins=40,normed=True,cmap=cmocean.cm.gray_r,alpha=0.9)
plt.colorbar()
medalpha=(16.*dat['medO']+28.*dat['medSi']+24.*dat['medMg'])/(16.+24.+28.)
plt.plot(dat['medFe'],medalpha,c='k',alpha=0.5)
plt.ylabel(r'[$\alpha$/Fe]',fontsize=14)
plt.xlabel(r'[Fe/H]',fontsize=14)
plt.title('TNG Msun=100 - free N1a',fontsize=14)
plt.show()
# Out:
# /home/ohep2/.local/lib/python2.7/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
plt.plot(dat['medSFR'])
plt.show()
