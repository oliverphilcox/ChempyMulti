# %%
# %pylab inline
from scipy.stats import beta
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0,1,500)
plt.figure()
for a in [1,1.3,1.7,2,3,5,15,30]:
    plt.plot(x,beta.pdf(x,1,a)/a,label='%.1f' %(a))
plt.legend(loc='upper right')
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
plt.xlabel(r'$x$',fontsize=16)
plt.ylabel(r'$\beta(x)$',fontsize=16)
plt.title(r'$\beta(x; k, 1)$ plot for various k',fontsize=16)
plt.savefig('Presentation/beta.pdf',dpi=300)

# %%
x = np.linspace(0,10,100)
y = 0.5*x**2-3*x-1
y2 = -0.3*x**2+x-5
plt.plot(x,y,label=r'\chi1')
plt.plot(x,y2,label=r'\chi2')
plt.legend()
plt.rc(usetex = True, fontfamily=serif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8dbd3ed7eebb> in <module>()
#       5 plt.plot(x,y2,label=r'\chi2')
#       6 plt.legend()
# ----> 7 plt.rc(usetex = True, fontfamily=serif)
#
# NameError: name 'serif' is not defined
