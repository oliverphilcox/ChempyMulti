# %%
# %pylab inline
from scipy.stats import beta
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/philcox/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['beta']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
plt.clf()
fig = plt.figure(figsize=(8.69,6.69), dpi=300)
ax = fig.add_subplot(111)

### Tidy up plot
text_size=20
large_text = 30
label_size = 18
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=large_text, lw=1.)
plt.rc('lines', linewidth = 1.)
params = {'text.latex.preamble': r"\usepackage{libertine}",'text.usetex' : True,'font.size' : text_size,'font.family' : 'libertine','text.latex.unicode': True}
plt.rcParams.update(params)
###

plt.legend(loc='upper right')
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x;1,\beta)/\beta$')
plt.ylim([-0.02,1.08])
plt.xlim([-0.0,1.0])

x = linspace(0,1,500)
x_label = [0.92,0.9,0.8,0.7,0.6,0.4,0.15,0.03]
beta_log_param = [0.0,0.15,0.3,0.45,0.6,0.9,1.5,3]
list_of_beta_params = [10**item for item in beta_log_param] #np.logspace(0,3,20)
for i,a in enumerate(list_of_beta_params):
    ax.plot(x,beta.pdf(x,1,a)/a,label='%.2f' %(beta_log_param[i]))
    ax.annotate(xy = (x_label[i],beta.pdf(x_label[i],1,a)/a+0.02) ,s = beta_log_param[i],fontsize=label_size,color='C%s' %(i))



fig.savefig('PaperPlots/beta.pdf',bbox_inches='tight')
# Out:
# /home/philcox/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %pylab inline
x = np.linspace(0,10,100)
y = 0.19*x**2-0.5*x+2.5
y2 = 0.05*x**2-0.3*x+1
text_size=16
fig = plt.figure()
plt.clf()
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size/1.3)
plt.rc('ytick', labelsize=text_size/1.3)
plt.rc('axes', labelsize=text_size, lw=1.)
plt.rc('lines', linewidth = 1.)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
ax1=fig.add_subplot(111)
l1 = ax1.plot(x,y,label=r'$(\chi_1)$')
l2 = ax1.plot(x,y2,label=r'$\chi_2$')
ax2 = ax1.twinx()
l3 = ax2.plot(x,y/y2,label=r'$K$',c='r',ls='--')
lns = l1 + l2 + l3
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)
ax2.set_ylabel(r'$K_1/K_2$')
ax1.set_ylabel(r'$P(\mathcal{O}|\chi)$')
ax1.set_xlabel('k')
savefig('Kplot.pdf',dpi=300,bbox_inches='tight')

# %%
np.logspace(0,3,20)

# %%
dat=np.load('Chempy/input/stars/Proto-sun_all.npy')
abu = dat[0]
for j,item in enumerate(dat.dtype.names):
    print(item, abu[j])
# Out:
# He 0.01
# C 0.0
# N 0.0
# O 0.0
# F 0.0
# Ne 0.0
# Na 0.0
# Mg 0.0
# Al 0.0
# Si 0.0
# P 0.0
# S 0.0
# Cl 0.0
# Ar 0.0
# K 0.0
# Ca 0.0
# Sc 0.0
# Ti 0.0
# V 0.0
# Cr 0.0
# Mn 0.0
# Fe 0.04
# Co 0.0
# Ni 0.0
# Cu 0.0
# Zn 0.0
# Ga 0.0
# Ge 0.0
# age 4.56
