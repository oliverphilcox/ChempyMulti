# %%
from Chempy.score_function import Bayes_score
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %timeit -r 1 -n 1 Bayes_score()
# Out:
# Finding posterior parameter values
# ['Proto-sun_all']
# first minimization for each star separately took:  0 seconds
# step  1 of  1000
# -4.12976604151 -4.13213621987
# calculation so far took 1.567366600036621  seconds
# step  2 of  1000
# -4.12976604151 -4.12953038925
# calculation so far took 1.891874074935913  seconds
# step  3 of  1000
# -4.12976604151 -4.12984644512
# calculation so far took 2.238574981689453  seconds
# step  4 of  1000
# -4.12976604151 -4.14629640795
# calculation so far took 2.5672876834869385  seconds
# step  5 of  1000
# -4.12976604151 -4.15727896224
# calculation so far took 3.090660572052002  seconds
# step  6 of  1000
# -4.12976604151 -4.16600218673
# calculation so far took 3.4240636825561523  seconds
# step  7 of  1000
# -4.12976604151 -4.21690483837
# calculation so far took 3.7494266033172607  seconds
# step  8 of  1000
# -4.12976604151 -4.29300387652
# calculation so far took 4.07443642616272  seconds
# step  9 of  1000
# ...
