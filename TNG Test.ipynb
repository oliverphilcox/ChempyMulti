# %%
# %pylab inline
from Chempy.yields import SN2_feedback
chi = SN2_feedback()
getattr(chi,'chieffi04_net')()
tng = SN2_feedback()
getattr(tng,'TNG_net')()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tng_tab = tng.table[tng.metallicities[-1]]
chi_tab = chi.table[0.02]

print('Property \t TNG \t C04')
print('------------------------------------------------')

for item in tng_tab.dtype.names:
    if item in chi_tab.dtype.names:
        print('%s \t\t %.2e \t\t %.2e' %(item,tng_tab[item][3],chi_tab[item][0]))
# Out:
# Property 	 TNG 	 C04
# ------------------------------------------------
# Mass 		 1.30e+01 		 1.30e+01
# mass_in_remnants 		 3.22e-01 		 1.09e-01
# unprocessed_mass_in_winds 		 6.78e-01 		 8.91e-01
# H 		 -1.42e-01 		 -1.32e-01
# He 		 9.89e-02 		 8.59e-02
# C 		 2.32e-03 		 5.47e-03
# N 		 2.47e-03 		 2.56e-03
# O 		 1.48e-02 		 1.51e-02
# Ne 		 3.97e-03 		 3.39e-03
# Mg 		 4.10e-03 		 2.70e-03
# Si 		 5.68e-03 		 5.00e-03
# S 		 2.32e-03 		 2.00e-03
# Ca 		 2.15e-04 		 2.59e-04
# Fe 		 6.91e-03 		 7.79e-03

# %%
tng.table
# Out:
# {0.0: rec.array([ (   8.,  0.3966521 ,  0.6033479 , -0.16019768,  0.13567461,  0.00711698,   2.52895989e-05,  0.01685124,  0.00127722,  -2.52160462e-05,  -3.63331579e-04,  -2.60699104e-04,  -2.53626640e-05,  -7.30494503e-05),
#   (   9.,  0.37298128,  0.62701873, -0.19193374,  0.12543634,  0.0121886 ,   2.00073428e-05,  0.02884331,  0.00217683,   1.35489763e-03,   6.18294952e-03,   2.59380671e-03,   4.19215969e-04,   1.27177667e-02),
#   (  12.,  0.32589659,  0.6741034 , -0.2608093 ,  0.09550722,  0.01611865,   2.33749943e-05,  0.09760322,  0.01839286,   4.82401485e-03,   1.23110982e-02,   6.07923698e-03,   9.49956942e-04,   8.99967831e-03),
#   (  13.,  0.33403733,  0.66596267, -0.22764127,  0.12442323,  0.00657194,   2.96152866e-04,  0.06153645,  0.00246668,   1.39359254e-02,   1.11108366e-02,   3.09863081e-03,   3.25413304e-04,   3.87600716e-03),
# ...
