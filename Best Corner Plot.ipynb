# %% [markdown]
# ## Create corner plot of best yield set

# %%
# %load init.ipy
# %pylab inline
from Chempy.parameter import ModelParameters
a = ModelParameters()
from Chempy.score_function import preload_params_mcmc
preload = preload_params_mcmc()
print(a.yield_table_name_sn2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# NuGrid_net

# %%
from Chempy.plot_mcmc import plot_mcmc_chain_with_prior,restructure_chain
from Chempy.wrapper import single_star_optimization

# %% [markdown]
# ## *Oversample by x10 for paper plot + check network. Save this somewhere*

# %%
single_star_optimization()
# Out:
# ['Proto-sun_all']
# first minimization for each star separately took:  0 seconds
# step  1 of  1000
# 2.50400785935 2.50277812288
# calculation so far took 1.5874066352844238  seconds
# step  2 of  1000
# 2.50400785935 2.50172363407
# calculation so far took 1.8841521739959717  seconds
# step  3 of  1000
# 2.50400785935 2.50072496857
# calculation so far took 2.1852753162384033  seconds
# step  4 of  1000
# 2.50400785935 2.49637578761
# calculation so far took 2.4812939167022705  seconds
# step  5 of  1000
# 2.50400785935 2.49111096733
# calculation so far took 2.7980661392211914  seconds
# step  6 of  1000
# 2.50400785935 2.47789164553
# calculation so far took 3.1176066398620605  seconds
# step  7 of  1000
# 2.50400785935 2.45943208424
# calculation so far took 3.4473743438720703  seconds
# step  8 of  1000
# 2.50400785935 2.4156441878
# calculation so far took 3.7796621322631836  seconds
# step  9 of  1000
# 2.50400785935 2.33561732259
# ...

# %%
restructure_chain('BestMCMC/',parameter_names=a.parameter_names)
# Out:
# blob shape =  (64, 303, 8, 1) probably some runs did not return results and were stored anyway.
# The chain has a length of 303 iterations, each iteration having 64 evaluations/walkers
# Mean posteriors at the beginning and the end of the chain:
# 0.304305136827 2.50400785935
# Mean posteriors after the burn-in tail is cut out:
# 0.304305136827 0.190916234049
# We are left with a sample of 4992 posterior evaluations from the converged MCMC chain
# We have 4992 iterations good enough posterior, their posteriors range from
# 3.25414898157 -9.93614910631
# Highest posterior was obtained at parameters:  [[ 0.79955457 -2.04061725 -3.2254755  -0.06260366  0.54786355  0.55733585]]
# Number of unique posterior values:  2545
# Inferred marginalized parameter distributions are:
# 0 0.698255229184 +- 0.367117797097
# 1 -1.97041555922 +- 0.221921134421
# 2 -3.17123855184 +- 0.212148075301
# 3 -0.287602747238 +- 0.354401559135
# 4 0.577012027743 +- 0.0910307407951
# ...

# %%
# %pylab inline
from Chempy.plot_mcmc import plot_mcmc_chain_with_prior
plot_mcmc_chain_with_prior('BestMCMC/',use_prior=True,only_first_star=False,plot_true_parameters=False,plot_only_SSP_parameter=False)
# Out:
# Populating the interactive namespace from numpy and matplotlib
