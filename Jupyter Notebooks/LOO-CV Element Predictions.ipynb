# %%
# %load init.ipy
# %pylab inline
from Chempy.parameter import ModelParameters
a = ModelParameters()
from Chempy.score_function import preload_params_mcmc
preload = preload_params_mcmc()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dat = np.load('/home/philcox/Save/OVERALL/Hogg_element_predictions_Nomoto2013_net.npz')
mean=dat['mean']
sigma=dat['sigma']
elements=dat['elements']
likelihood=dat['likelihood']
dat.close()

dat2 = np.load('/home/philcox/Save/OVERALL/Hogg_element_predictions_chieffi04_net.npz')
mean2=dat2['mean']
sigma2=dat2['sigma']
elements2=dat2['elements']
likelihood2=dat2['likelihood']
dat2.close()

dat3 = np.load('/home/philcox/Save/OVERALL/Hogg_element_predictions_Frischknecht16_net.npz')
mean3=dat3['mean']
sigma3=dat3['sigma']
elements3=dat3['elements']
likelihood3=dat3['likelihood']
dat3.close()

# Load in proto-solar data
ps_dat = np.load('Chempy/input/stars/Proto-sun_all.npy')
ps_nam = ps_dat.dtype.names
ps_abun = []; ps_err = []
for el in elements:
    for i in range(len(ps_nam)):
        if ps_nam[i] == el:
            ps_abun.append(ps_dat[0][i])
            ps_err.append(ps_dat[1][i])

# %%
plt.figure(figsize=(20,10))
large_text = 28
text_size = 22
marker_size= 10
plt.rc('font', family='serif',size = large_text)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.0)
plt.rc('lines', linewidth = 2)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,
    'font.family' : 'libertine',
    'text.latex.unicode': True,
    }
plt.rcParams.update(params)

# Iterate over trials

plt.errorbar(np.arange(len(elements)),mean[9],yerr=sigma[9],fmt='s',ms=marker_size,c='k',alpha=0.5,label='N13')
plt.errorbar(np.arange(len(elements)),mean2[9],yerr=sigma2[9],fmt='o',ms=marker_size,c='r',alpha=0.5,label='C04')
plt.errorbar(np.arange(len(elements)),mean3[9],yerr=sigma3[9],fmt='o',ms=marker_size,c='g',alpha=0.5,label='F16')

plt.errorbar(np.arange(len(elements)),ps_abun,yerr=ps_err,fmt='x',ms=marker_size,c='b',label='Observations')
plt.ylabel('[X/Fe] abundance')
plt.xlabel('Cross Validation Element')
plt.legend(loc='lower left',)
ax=plt.gca()
elements = elements.astype("<U6")
for e,el in enumerate(elements):
    if el == 'Fe':
        elements[e] = '[Fe/H]'
la=plt.setp(ax,xticks=np.arange(len(elements)), xticklabels=elements)
plt.savefig('PaperPlots/element_prediction.pdf',dpi=300)

# %%
# Out:
# array(['Al', 'Ar', 'C', 'Ca', 'Cl', 'Co', 'Cr', 'Cu', 'F', '[F', 'Ga',
#        'Ge', 'He', 'K', 'Mg', 'Mn', 'N', 'Na', 'Ne', 'Ni', 'O', 'P', 'S',
#        'Sc', 'Si', 'Ti', 'V', 'Zn'],
#       dtype='<U6')

# %%
score = np.zeros(len(likelihood))
for i in range(len(likelihood)):
    score[i]=np.product(likelihood[i])
score2 = np.zeros(len(likelihood2))
for i in range(len(likelihood2)):
    score2[i]=np.product(likelihood2[i])

# %%
plt.semilogy(np.arange(len(score)),score)
#plt.semilogy(np.arange(len(score2)),score2)

# %%
j = 23
i=9
m=mean[i][j]
print(m)
s=sigma[i][j]
print(s)
p=ps_abun[i]
pe = ps_err[i]
l=(2.*np.pi*(pe*pe+s*s))**(-0.5)*np.exp(-(p-m)**2/(2*(s**2+pe**2)))
print(l)
# Out:
# -1.01768038778
# 0.090167848039
# 5.44319954008e-23

# %%
for j in range(28):
    print(j)
    for i in range(10):
        print(likelihood[i][j])
# Out:
# 0
# 3.06116205813
# 2.98842517532
# 3.01700822241
# 3.11053952542
# 2.80300877427
# 2.88420122473
# 2.96294351059
# 2.92742335116
# 3.19417968827
# 2.96817374627
# 1
# 2.4010145338
# 2.36074819263
# 2.26375466225
# 2.21959974336
# 2.26516424629
# 2.3200927228
# 2.28094335017
# 2.21454758982
# 2.22534445591
# 2.30070735174
# 2
# 1.2085113128
# 1.01032679386
# 0.998408615843
# 1.14630421651
# 1.06675410339
# 0.957087235779
# 0.942790458164
# 1.16436442304
# 1.0559522847
# 0.88649348593
# 3
# 4.95103157095
# 5.26660745779
# 5.16115679458
# 5.25535757948
# 4.52819537441
# 5.05098978013
# 5.45997365566
# 5.19435147586
# 5.10032151563
# 5.12123032698
# 4
# 4.18211567127e-06
# 3.66028413903e-06
# 3.47425813519e-06
# 1.46831082697e-06
# 2.08511001228e-06
# 4.55690186675e-06
# 8.17220868744e-06
# 1.74908370674e-05
# 3.83319698062e-06
# 1.20725759918e-06
# 5
# 0.00589705385248
# 0.00348482910363
# 0.00731243180064
# 0.00530307085339
# 0.00703335104365
# 0.00502566699528
# 0.00557666346226
# 0.00585603941744
# 0.0100943215711
# 0.00557885745388
# 6
# 0.613176443249
# 0.609230683846
# 0.633926051213
# 0.551581650513
# 0.616860833576
# 0.655684417229
# 0.633472879128
# 0.653640208822
# 0.609250508022
# 0.62110709602
# 7
# 3.1599595645
# 2.84251855099
# 3.07961701934
# 2.81574509737
# 2.96774160266
# 3.08854723747
# 2.87057238619
# 2.80942988318
# 2.83629160461
# 2.86058310272
# 8
# 3.56027210916
# 3.33790596246
# 3.29729698226
# 3.41260407906
# 3.3941857399
# 3.43086794502
# 3.63511942917
# 3.4035587154
# 3.48961984924
# 3.3985195632
# 9
# 2.61240455741
# 2.57796054456
# 2.40443133157
# 2.56617961371
# 2.66165472499
# 2.60103456584
# 2.6049369254
# 2.64216942542
# 2.52928897463
# 2.70080045739
# 10
# 0.155912969943
# 0.20416152714
# 0.175751374726
# 0.172863574599
# 0.247625411844
# 0.249630975248
# 0.213986077372
# 0.183309555964
# 0.234446651933
# 0.152990632934
# 11
# 0.00342099257637
# 0.00403059745989
# 0.00931076188615
# 0.00466239546766
# 0.00490923289676
# 0.00542506030804
# 0.00563911698635
# 0.0109806198262
# 0.00949784323566
# 0.00948196985917
# 12
# 2.53146424771
# 2.69249450974
# 3.13177521244
# 2.77260957919
# 2.70616494754
# 2.90891879516
# 2.86217609691
# 2.91098619467
# 2.78522515484
# 2.89582819451
# 13
# 1.75690187915e-14
# 1.38690890772e-14
# 1.07123005282e-14
# 2.9756863892e-14
# 3.28364282831e-14
# 1.12459816096e-14
# 8.15874435416e-15
# 6.76980296486e-15
# 3.11508858929e-14
# 2.46943790539e-14
# 14
# 4.07402115981
# 3.96091517392
# 3.72438164655
# 4.16375758876
# 4.06685122753
# 4.20092242417
# 4.02454682536
# 4.16740873492
# 3.86873276871
# 4.15210477571
# 15
# 0.408669470273
# 0.365008693876
# 0.376793546156
# 0.651599007826
# 0.47510558851
# 0.533191725997
# 0.449781447404
# 0.336570443491
# 0.473056935132
# 0.360027779105
# 16
# 1.50167648719
# 1.58313421141
# 1.66746283396
# 1.68058768964
# 1.75233089095
# 1.50614546329
# 1.60277857218
# 1.58475168278
# 1.96659015277
# 1.27757289263
# 17
# 0.0396188078295
# 0.0776845150932
# 0.0860289364081
# 0.0583747552061
# 0.0672964273768
# 0.0458490094611
# 0.051731706954
# 0.0338234288249
# 0.0348173827007
# 0.0345999474464
# 18
# 0.349773504707
# 0.421882806103
# 0.327747380378
# 0.318611370601
# 0.341430619694
# 0.317579906992
# 0.310135025544
# 0.366931674284
# 0.338999614489
# 0.358241453342
# 19
# 0.573721688735
# 0.837023123249
# 0.754609660133
# 0.557994243708
# 0.552252181096
# 0.680113525845
# 0.734924030754
# 0.675668410379
# 0.51212618588
# 0.617670589621
# 20
# 1.45895985722
# 1.33458040927
# 1.62481008706
# 1.52872402508
# 1.23165995533
# 1.53877689742
# 1.56706995957
# 1.37656495942
# 1.42749873077
# 1.38093893703
# 21
# 3.75430049648
# 3.53934171208
# 3.65666553507
# 3.57346054849
# 3.80433847899
# 3.99771237331
# 4.00388610109
# 3.75493960545
# 3.38438385413
# 3.57110945121
# 22
# 0.00611125836525
# 0.0127131045256
# 0.00479998071696
# 0.00279882049646
# 0.00372971261062
# 0.00337921132341
# 0.00419939285397
# 0.00473508371397
# 0.00356248496654
# 0.00178449129857
# 23
# 2.17271901123e-20
# 7.2807542757e-22
# 4.01487532945e-21
# 1.97646856469e-20
# 7.47873026307e-24
# 3.50178385553e-23
# 2.15857079739e-20
# 2.26901499894e-21
# 2.29418769002e-21
# 2.70156797764e-21
# 24
# 0.000280061279655
# 0.000293912900727
# 0.000344291861287
# 0.000527002396161
# 0.000615060931296
# 0.000510745130684
# 0.000932813076155
# 0.000227708880205
# 0.000379272279122
# 0.000269371842299
# 25
# 7.64835048834e-07
# 8.55834056321e-07
# 8.64253799151e-07
# 3.37096182756e-07
# 6.42119584114e-07
# 1.22395858984e-06
# 6.24965189633e-07
# 9.15222110111e-07
# 7.86169021882e-07
# 4.50721831413e-07
# 26
# 0.127805412651
# 0.128214857106
# 0.128200373866
# 0.12806263322
# 0.130417131619
# 0.126935713713
# 0.127746247565
# 0.126641247423
# 0.127147725285
# 0.1274460214
# 27
# 3.58659788568
# 3.56904187195
# 3.29881718061
# 3.31441757079
# 3.56412336982
# 3.29894403756
# 3.49173791583
# 3.49152560292
# 3.58924188468
# 3.40991565866

# %%
elements[23]
# Out:
# 'Sc'

# %%
plt.legend?
