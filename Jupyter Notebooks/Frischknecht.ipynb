# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d1 = np.load('/home/philcox/Save/OVERALL/Bayes_score - chieffi04_net, Karakas_net_yield, Seitenzahl.npz')
d2 = np.load('/home/philcox/Save/OVERALL/Bayes_score - Nomoto2013_net, Karakas_net_yield, Seitenzahl.npz')
#d3 = np.load('/home/philcox/Save/OVERALL/Bayes_score - Frischknecht16_net, Karakas_net_yield, Seitenzahl.npz')
e1 = np.load('/home/philcox/Save/OVERALL/ErrorHogg - chieffi04_net, Karakas_net_yield, Seitenzahl.npz')
e2 = np.load('/home/philcox/Save/OVERALL/ErrorHogg - Nomoto2013_net, Karakas_net_yield, Seitenzahl.npz')
#e3 = np.load('/home/philcox/Save/OVERALL/ErrorHogg - Frischknecht16_net, Karakas_net_yield, Seitenzahl.npz')
d = [d1,d2,d3]
e = [e1,e2,e3]
name=['C04','N13','F16']

# %%
print("Bayes Scores \t\t CV Score")
for i in range(2):
    print('%s: %.3f +/- %.3f \t %.3f + %.3f - %.3f' %(name[i],np.log10(d[i]['score']),d[i]['score_err']/(d[i]['score']*np.log(10)),e[i]['median'],e[i]['upper']-e[i]['median'],e[i]['median']-e[i]['lower']))
# Out:
# Bayes Scores 		 CV Score
# C04: -0.976 +/- 0.003 	 -28.379 + 0.394 - 0.471
# N13: -5.421 +/- 0.003 	 -55.656 + 0.761 - 2.000

# %%
B_Chi = np.load('/home/philcox/Save/New_SCORES/Chieffi/Bayes_score - chieffi04_net, Karakas_net_yield, Seitenzahl.npz')
B_Def = np.load('/home/philcox/Save/New_SCORES/Default/Bayes_score - Nomoto2013_net, Karakas_net_yield, Seitenzahl.npz')
B_Fri = np.load('/home/philcox/Save/New_SCORES/Frischknecht/Bayes_score - Frischknecht16_net, Karakas_net_yield, Seitenzahl.npz')
beta_param = B_Chi['beta_param']
scoreBC = B_Chi['score']
scoreBD = B_Def['score']
scoreBF = B_Fri['score']
score_errBC = B_Chi['score_err']
score_errBD = B_Def['score_err']
score_errBF = B_Fri['score_err']
B_Chi.close()
B_Def.close()
B_Fri.close()

# %%
scores = [scoreBD,scoreBC,scoreBF]
errors = [score_errBD,score_errBC,score_errBF]
names = ['N13','C04','F16']
shapes = ['x','v','.','^']
colors = ['k','r','b','g']

# %%
# Plot parameters
text_size = 26
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.0)
plt.rc('lines', linewidth = 1)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,
        'font.family' : 'libertine',
        'text.latex.unicode': True}
plt.rcParams.update(params)
fig = plt.figure(figsize=(15.69,8.27), dpi=300)
      

for i in [0,1,2]:
    plt.errorbar(np.log10(beta_param),scores[i]/max(scores[i]),yerr=errors[i],fmt=shapes[i],label=names[i],ms=10,c=colors[i],alpha=0.5) 
    plt.text(2.4,0.95-0.08*i,names[i],color=colors[i])
plt.xlabel(r'$\log_{10}(\beta)$')
plt.ylabel(r'Normalized $\mathrm{P}(\mathcal{O}_s|\chi)$')
#plt.legend()
#plt.savefig('PaperPlots/RescaledEvidence.pdf',bbox_inches="tight")

# %%
text_size = 26
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.0)
plt.rc('lines', linewidth = 1)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,
        'font.family' : 'libertine',
        'text.latex.unicode': True}
plt.rcParams.update(params)
fig = plt.figure(figsize=(15.69,8.27), dpi=300)

for i in [0,1,2]:
    log_error = errors[i]/(scores[i]*np.log(10))
    plt.errorbar(np.log10(beta_param),np.log10(scores[i]),fmt=shapes[i],yerr = log_error,label=names[i],c=colors[i],ms=10,alpha=0.5)
    plt.text(-0.05,-58-6*i,names[i],color=colors[i])
plt.xlabel(r'$\log_{10}(\beta)$')
plt.ylabel(r'$\log_{10}(\mathrm{P}(\mathcal{O}_s|\chi))$')
#plt.legend()
#plt.title('Logarithmic Bayesian evidences')
#plt.savefig('PaperPlots/logEvidence.pdf',bbox_inches="tight")

# %%
# %pylab inline
# Load datasets
H_Chi = np.load('/home/philcox/Save/New_SCORES/Chieffi/Hogg_score - chieffi04_net, Karakas_net_yield, Seitenzahl.npz')
H_Def = np.load('/home/philcox/Save/New_SCORES/Default/Hogg_score - Nomoto2013_net, Karakas_net_yield, Seitenzahl.npz')
H_Fri = np.load('/home/philcox/Save/New_SCORES/Ventura/Hogg_score - Nomoto2013_net, Ventura, Seitenzahl.npz')
beta_param = H_Chi['beta_param']
scoreHC = H_Chi['score']
scoreHD = H_Def['score']
scoreHF = H_Fri['score']
H_Chi.close()
H_Def.close()
H_Fri.close()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/philcox/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['colors', 'e']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
scores2 = [scoreHD,scoreHC,scoreHF]
names = ['N13','C04','F16']
shapes = ['x','v','.','^']
colors = ['k','r','b','g']

# %%
# Plot parameters
text_size = 26
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.0)
plt.rc('lines', linewidth = 1)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,
        'font.family' : 'libertine',
        'text.latex.unicode': True}
plt.rcParams.update(params)
fig = plt.figure(figsize=(15.69,8.27), dpi=300)
      

for i in [0,1,2]:
    plt.errorbar(np.log10(beta_param),scores2[i]/max(scores2[i]),fmt=shapes[i],label=names[i],ms=10,c=colors[i],alpha=0.4) 
    plt.text(2.4,0.95-0.08*i,names[i],color=colors[i])
plt.xlabel(r'$\log_{10}(\beta)$')
plt.ylabel(r'Normalized $\mathrm{L}_\mathrm{CV}$')
#plt.title('Rescaled LOO-CV score')
#plt.legend()
#plt.savefig('PaperPlots/RescaledHogg.pdf',bbox_inches="tight")

# %%
text_size = 26
plt.rc('font', family='serif',size = text_size)
plt.rc('xtick', labelsize=text_size)
plt.rc('ytick', labelsize=text_size)
plt.rc('axes', labelsize=text_size, lw=1.0)
plt.rc('lines', linewidth = 1)
plt.rcParams['ytick.major.pad']='8'
plt.rcParams['text.latex.preamble']=[r"\usepackage{libertine}"]
params = {'text.usetex' : True,
        'font.family' : 'libertine',
        'text.latex.unicode': True}
plt.rcParams.update(params)
fig = plt.figure(figsize=(15.69,8.27), dpi=300)

for i in [0,1,2]:
    plt.errorbar(np.log10(beta_param),np.log10(scores2[i]),fmt=shapes[i],label=names[i],c=colors[i],ms=10,alpha=0.6) 
    plt.text(-0.05,-100-7*i,names[i],color=colors[i])
plt.xlabel(r'$\log_{10}(\beta)$')
plt.ylabel(r'$\log_{10}(\mathrm{L}_\mathrm{CV})$')
#plt.legend()
#plt.title('Logarithmic LOO-CV scores')
#plt.savefig('PaperPlots/logHogg.pdf',bbox_inches="tight")
